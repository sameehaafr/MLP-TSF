# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd 
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("ad_viz_plotval_data.csv")
df.head(10)
# Out:
#          Date Source   Site ID  POC  Daily Mean PM10 Concentration     UNITS  \
# 0  01/01/2021    AQS  60070008    3                             24  ug/m3 SC
# 1  01/02/2021    AQS  60070008    3                             21  ug/m3 SC
# 2  01/03/2021    AQS  60070008    3                             19  ug/m3 SC
# 3  01/04/2021    AQS  60070008    3                             10  ug/m3 SC
# 4  01/05/2021    AQS  60070008    3                             12  ug/m3 SC
# 5  01/06/2021    AQS  60070008    3                             19  ug/m3 SC
# 6  01/07/2021    AQS  60070008    3                             16  ug/m3 SC
# 7  01/08/2021    AQS  60070008    3                             19  ug/m3 SC
# 8  01/09/2021    AQS  60070008    3                             12  ug/m3 SC
# 9  01/10/2021    AQS  60070008    3                             19  ug/m3 SC
#
#    DAILY_AQI_VALUE          Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# ...

# %%
df_PM10 = df[["Date", "Daily Mean PM10 Concentration"]]
df_PM10.head()
# Out:
#          Date  Daily Mean PM10 Concentration
# 0  01/01/2021                             24
# 1  01/02/2021                             21
# 2  01/03/2021                             19
# 3  01/04/2021                             10
# 4  01/05/2021                             12

# %%
df_PM10 = df_PM10.groupby(df_PM10["Date"])["Daily Mean PM10 Concentration"].sum()
df_PM10.head()
# Out:
# Date
# 01/01/2021    1454
# 01/02/2021    1533
# 01/03/2021    1578
# 01/04/2021    2474
# 01/05/2021    1479
# Name: Daily Mean PM10 Concentration, dtype: int64

# %% [markdown]
# # Data Cleaning
# # Data Normalization
# # Splitting Dataset
# # LSTM Model Building
# # Training
# # Predictions/Accuracy

# %%
df_PM10 = pd.DataFrame(df_PM10)

# %%
df_PM10.columns
# Out:
# Index(['Daily Mean PM10 Concentration'], dtype='object')

# %%
# Using the first 60 percent of the dataset for training. 
df_PM10.shape[0]
training_df = df_PM10.head(219)
training_df.columns = ['Date', 'Daily PM Concentration']
training_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/sameehaafr/Leetcode/sigai-tsf/lstm.ipynb Cell 8 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/sameehaafr/Leetcode/sigai-tsf/lstm.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> df_PM10.shape[0]
#       <a href='vscode-notebook-cell:/Users/sameehaafr/Leetcode/sigai-tsf/lstm.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> training_df = df_PM10.head(219)
# ----> <a href='vscode-notebook-cell:/Users/sameehaafr/Leetcode/sigai-tsf/lstm.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> training_df.columns = ['Date', 'Daily PM Concentration']
#       <a href='vscode-notebook-cell:/Users/sameehaafr/Leetcode/sigai-tsf/lstm.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> training_df
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
# ...

# %%
df_PM10
# Out:
#             Daily Mean PM10 Concentration
# Date
# 01/01/2021                           1454
# 01/02/2021                           1533
# 01/03/2021                           1578
# 01/04/2021                           2474
# 01/05/2021                           1479
# ...                                   ...
# 12/27/2021                            779
# 12/28/2021                            595
# 12/29/2021                            529
# 12/30/2021                            924
# 12/31/2021                           1078
#
# [365 rows x 1 columns]

# %%
X_train = df_PM10["Date"]
# x_test = 
# Y_train = 
# y_train =
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# training values for PM10 concentration

y_train = training_df.tolist();
y_train
# Out:
# [1454,
#  1533,
#  1578,
#  2474,
#  1479,
#  1621,
#  1985,
#  1909,
#  1839,
#  2570,
#  1806,
#  2085,
#  2375,
#  1971,
#  2024,
#  3418,
#  1869,
#  2608,
#  4252,
#  2288,
#  2338,
#  2489,
#  702,
#  699,
#  949,
#  872,
#  981,
#  1449,
#  536,
#  836,
#  1038,
#  1164,
#  1010,
#  2051,
#  1266,
#  1650,
#  2100,
#  1892,
#  2055,
#  3135,
#  1956,
#  1866,
#  1285,
#  1849,
#  991,
#  1919,
#  1480,
#  1269,
#  1442,
#  1502,
#  1875,
#  1812,
#  1340,
#  1712,
#  4046,
#  3370,
#  2462,
#  4178,
#  1632,
#  1671,
#  1984,
#  2136,
#  1728,
#  3225,
#  2967,
#  1356,
#  2085,
#  1840,
#  782,
#  714,
#  884,
#  1307,
#  1184,
#  2742,
#  1196,
#  2274,
#  1379,
#  1275,
#  1253,
#  1094,
#  1438,
#  4058,
#  1724,
#  2082,
#  1514,
#  1443,
#  1288,
#  3505,
#  2696,
#  2336,
#  2483,
#  2472,
#  2125,
#  2844,
#  3230,
#  2490,
#  2688,
#  2381,
#  2480,
#  3846,
#  2517,
#  2763,
#  6700,
#  3043,
#  2419,
#  3961,
#  2115,
#  1547,
#  2335,
#  2810,
#  3310,
#  3511,
# ...

# %% [markdown]
# Loading Libraries

# %% [markdown]
# Loading Data

# %% [markdown]
# Data Cleaning

# %% [markdown]
# Data Normalization

# %%
values = df.values
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_dataset = scaler.fit_transform(values)

# %% [markdown]
# Data Splitting

# %%
# Using the first 60 percent of the dataset for training. 
df_PM10.shape[0]
training_df = df_PM10.head(219)
train = training_df
# Out:
# Date
# 01/01/2021    1454
# 01/02/2021    1533
# 01/03/2021    1578
# 01/04/2021    2474
# 01/05/2021    1479
#               ...
# 08/03/2021    2302
# 08/04/2021    2731
# 08/05/2021    2795
# 08/06/2021    3344
# 08/07/2021    4373
# Name: Daily Mean PM10 Concentration, Length: 219, dtype: int64
